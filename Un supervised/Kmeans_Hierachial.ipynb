# %%
#unsupervised Machine Learning
- Kemans - This works by the concpet of centroid, it takes a random point and keeps moving tlill it reaches the centre of the cluster
- Hierachial  - Denodogram.

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"/content/income.csv")
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
df = df.rename(columns={"Income($)":"Income"})

# %%
plt.scatter(df.Age,df["Income"])
plt.xlabel('Age')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
df
# Out:
#         Name  Age  Income
# 0        Rob   27   70000
# 1    Michael   29   90000
# 2      Mohan   29   61000
# 3     Ismail   28   60000
# 4       Kory   42  150000
# 5     Gautam   39  155000
# 6      David   41  160000
# 7     Andrea   38  162000
# 8       Brad   36  156000
# 9   Angelina   35  130000
# 10    Donald   37  137000
# 11       Tom   26   45000
# 12    Arnold   27   48000
# 13     Jared   28   51000
# 14     Stark   29   49500
# 15    Ranbir   32   53000
# 16    Dipika   40   65000
# 17  Priyanka   41   63000
# 18      Nick   43   64000
# 19      Alia   39   80000
# 20       Sid   41   82000
# 21     Abdul   39   58000

# %%
#preprocessing
scaler = MinMaxScaler()
scaler.fit(df[['Income']])
df['Income'] = scaler.transform(df[['Income']])

scaler.fit(df[['Age']])
df['Age'] = scaler.transform(df[['Age']])

df.head()
# Out:
#       Name       Age    Income
# 0      Rob  0.058824  0.213675
# 1  Michael  0.176471  0.384615
# 2    Mohan  0.176471  0.136752
# 3   Ismail  0.117647  0.128205
# 4     Kory  0.941176  0.897436

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(df[['Age','Income']])
df['cluster']= y_predicted
df
# Out:
#         Name       Age    Income  cluster
# 0        Rob  0.058824  0.213675        1
# 1    Michael  0.176471  0.384615        1
# 2      Mohan  0.176471  0.136752        1
# 3     Ismail  0.117647  0.128205        1
# 4       Kory  0.941176  0.897436        2
# 5     Gautam  0.764706  0.940171        2
# 6      David  0.882353  0.982906        2
# 7     Andrea  0.705882  1.000000        2
# 8       Brad  0.588235  0.948718        2
# 9   Angelina  0.529412  0.726496        2
# 10    Donald  0.647059  0.786325        2
# 11       Tom  0.000000  0.000000        1
# 12    Arnold  0.058824  0.025641        1
# 13     Jared  0.117647  0.051282        1
# 14     Stark  0.176471  0.038462        1
# 15    Ranbir  0.352941  0.068376        1
# 16    Dipika  0.823529  0.170940        0
# 17  Priyanka  0.882353  0.153846        0
# 18      Nick  1.000000  0.162393        0
# 19      Alia  0.764706  0.299145        0
# 20       Sid  0.882353  0.316239        0
# ...

# %%
km.cluster_centers_
# Out:
# array([[0.85294118, 0.2022792 ],
#        [0.1372549 , 0.11633428],
#        [0.72268908, 0.8974359 ]])

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]

plt.scatter(df1.Age,df1['Income'],color='green')
plt.scatter(df2.Age,df2['Income'],color='red')
plt.scatter(df3.Age,df3['Income'],color='black')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label='centroid')
plt.xlabel('Age')
plt.ylabel('Income')
plt.legend()

# %%
#elbow Method

k_rng = range(1,10) #no of cluster as 1 to 10
sse = [] #initialise the SSE as an Empty List
for k in k_rng:
  km = KMeans(n_clusters=k)
  km.fit(df[['Age','Income']])
  sse.append(km.inertia_) #SSE of each cluster points aggregated (N =3 then interia is SSE1+SSE2+SSE3)

# %%
plt.xlabel('K')
plt.ylabel('SSE')
plt.plot(k_rng,sse)

# %%
#Hierachial
import numpy as np
import pandas as pd
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"/content/Mall_Customers.csv")
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
subset = data[['Annual Income (k$)','Spending Score (1-100)']]
subset.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
plt.figure(figsize=(15,8))
plt.title('Customer Dendograms')
dend = sch.dendrogram(sch.linkage(subset,method='ward'))

# %%
plt.figure(figsize=(15,8))
plt.title('Customer Dendograms')
dend = sch.dendrogram(sch.linkage(subset,method='complete'))
plt.axhline(y=420,color='r',linestyle='--')

# %%
h_cluster = AgglomerativeClustering(n_clusters=3,linkage='ward')
y_hc = h_cluster.fit_predict(subset)

# %%
data['cluster']=y_hc
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      cluster
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...

# %%
plt.figure(figsize=(15,8))
plt.scatter(data['Annual Income (k$)'],data['Spending Score (1-100)'],c=data['cluster'],cmap='rainbow')
